# %% [markdown]
# This is a little exercise for testing your documentation searching and google searching skills. I have write down clearly the requirements and the expected outcome. If you get it wrong, try to ask questions properly in google search.

# %%
# Import NumPy
import ___ as np

# %%
# Create a NumPy array from a list
my_list = [1, 2, 3, 4, 5]
my_array = np.___(my_list)
print("My array:", type(my_array))

# %% [markdown]
# Expected result:
#
#
# ```
# <class 'numpy.ndarray'>
# ```

# %%
# Create a NumPy array of zeros
my_zeros = np.___(5)
print("Zeros:", my_zeros)

# %% [markdown]
# Expected result:
#
#
# ```
# Zeros: [0. 0. 0. 0. 0.]
# ```

# %%
# Create a NumPy array of ones
my_ones = np.___(5)
print("Ones:", my_ones)

# %% [markdown]
# Expected result:
#
#
# ```
# Ones: [1. 1. 1. 1. 1.]
# ```

# %%
# Create two NumPy array with a range of values, one is odd number from 0 to 10, another one is even number from 0 to 10
odd_numbers = np.arange( ___ , ___ , ___)
even_numbers = np.arange( ___ , ___, ___)
print("Odds:", odd_numbers)
print("Evens:", even_numbers)

# %% [markdown]
# Expected result:
#
#
# ```
# Odds: [1 3 5 7 9]
# Evens: [ 2  4  6  8 10]
# ```

# %%
# Reshape a NumPy array of 1(row)x6(column) to 2(row)x3(column)
even_numbers_with_zero = np.arange(___,___,___)
my_reshape = np.___(even_numbers_with_zero, (___, ___))
print("Reshaped array:\n", my_reshape)

# %% [markdown]
# Expected result:
#
#
# ```
# Reshaped array:
#  [[ 0  2  4]
#  [ 6  8 10]]
# ```

# %%
# Indexing and slicing a NumPy array

# Get the first element 0 from the even array
print("First element:", my_reshape[ ___ ])

# Get all elements in second row
print("Second row:", my_reshape[ ___ ])

# Get only the last column
print("Last column:", my_reshape[ ___ ])

# %% [markdown]
# Expected result:
#
#
# ```
# First element: 0
# Second row: [ 6  8 10]
# Last column: [ 4 10]
# ```

# %%
# Basic array operations
my_array1 = np.array([1, 2, 3])
my_array2 = np.array([4, 5, 6])

# Adding elements between two rows, i.e. [array1_column1+array2_column1, array1_column1+array2_column1, array1_column1+array2_column1]
print("Addition:", ___ )

# Substracting elements in two rows, i.e. [array1_column1-array2_column1, array1_column1-array2_column1, array1_column1-array2_column1]
print("Subtraction:", ___ )

# Multiplication elements in two rows, i.e. [array1_column1 x array2_column1, array1_column1 x array2_column1, array1_column1 x array2_column1]
print("Multiplication:", ___ )

# Division elements in two rows, i.e. [array1_column1 / array2_column1, array1_column1 / array2_column1, array1_column1 / array2_column1]
print("Division:", ___ )

# %% [markdown]
# Expected result:
#
# ```
# Addition: [5 7 9]
# Subtraction: [-3 -3 -3]
# Multiplication: [ 4 10 18]
# Division: [0.25 0.4  0.5 ]
# ```
